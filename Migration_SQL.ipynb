# %% [markdown]
# #### Añadir que es lo que instalo

# %%
import pandas as pd

# %%
#pip install openpyxl

# %%
#pip install SQLAlchemy

# %%
#pip install PyMySQL

# %%
#pip install mysqlclient

# %%
df_online_sales = pd.read_csv('Online_Sales_Final.csv', index_col=0)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql://ariana:AlumnaAdalab@localhost/online_sales')

# %%
df_online_sales
# Out:
#        Invoice No Stock Code   Description  Quantity  Unit Price  Customer ID  \
# 0          221958   SKU_1964     White Mug        38         2.0        37039
# 1          771155   SKU_1241     White Mug        18        41.0        19144
# 2          231932   SKU_1501    Headphones        49        29.0        50472
# 3          465838   SKU_1760     Desk Lamp        14        77.0        96586
# 4          359178   SKU_1386     USB Cable        30        68.0            0
# ...           ...        ...           ...       ...         ...          ...
# 49777      354083   SKU_1562      Blue Pen        25        71.0        51445
# 49778      296698   SKU_1930     USB Cable         7        52.0        28879
# 49779      177622   SKU_1766  Office Chair        43        85.0        21825
# 49780      701213   SKU_1602      Notebook        48        40.0        43199
# 49781      772215   SKU_1832     White Mug        30        38.0        53328
#
# ...

# %%
df_online_sales.to_sql(name='online_sales', con=engine, if_exists='append', index=False)
# Out:
# 49782
